# %%
import pandas as pd

# %% [markdown]
# # Extract

# %%
df = pd.read_csv("a_steam_data_2021_2025.csv")

df
# Out:
#          appid                        name  release_year  release_date  \
# 0      3057270           Seafarer's Gambit          2024   Jul 5, 2024
# 1      3822840    Capitalist Misadventures          2025  Jul 25, 2025
# 2      3216640  The Beast and the Princess          2025  Jun 17, 2025
# 3      2403620                 Air Twister          2023  Nov 10, 2023
# 4      1538040                Horde Slayer          2021  Mar 19, 2021
# ...        ...                         ...           ...           ...
# 65516  3097010           X Simulator Drone          2024  Jul 31, 2024
# 65517  3304930        Retro Dungeon Slayer          2025   Mar 3, 2025
# 65518  1461580            Molecule Builder          2021   Feb 4, 2021
# 65519  1379120                    MechNest          2024  Apr 13, 2024
# 65520  1580420     Ambidextrous Psychopath          2021  Jun 28, 2021
#
#                                                genres  \
# 0                 Action;Adventure;Indie;RPG;Strategy
# 1                    Casual;Indie;Simulation;Strategy
# 2                            Adventure;Indie;Strategy
# 3                              Action;Adventure;Indie
# 4      Action;Adventure;Casual;Indie;RPG;Early Access
# ...                                               ...
# 65516                         Casual;Indie;Simulation
# 65517                       Action;Indie;Early Access
# 65518                            Simulation;Education
# 65519                                    Action;Indie
# 65520                                    Casual;Indie
#
#                                               categories  price  \
# 0                           Single-player;Family Sharing   3.99
# 1              Single-player;Save Anytime;Family Sharing   7.99
# 2      Single-player;Steam Achievements;Full controll...  12.99
# 3      Single-player;Steam Achievements;Full controll...  24.99
# 4      Single-player;Steam Achievements;Full controll...   3.99
# ...                                                  ...    ...
# 65516                       Single-player;Family Sharing  14.99
# 65517                       Single-player;Family Sharing   4.99
# 65518  Single-player;Tracked Controller Support;VR On...  14.99
# 65519  Single-player;Partial Controller Support;Famil...  15.99
# 65520                       Single-player;Family Sharing   0.99
#
#        recommendations              developer              publisher
# 0                    0  Bouncy Rocket Studios  Bouncy Rocket Studios
# 1                    0       Caramelo Studios       Caramelo Studios
# 2                    0             Libragames             Libragames
# 3                    0                 YS Net                   ININ
# 4                    0       Wagner Rodrigues       Wagner Rodrigues
# ...                ...                    ...                    ...
# 65516                0           Inonia Games           Inonia Games
# 65517                0       Hard Shark Games       Hard Shark Games
# 65518                0        Xennial Digital        Xennial Digital
# 65519                0            PoisonGames            PoisonGames
# 65520                0           Rylan Yancey           Rylan Yancey
#
# [65521 rows x 10 columns]

# %% [markdown]
# # Transform

# %% [markdown]
# ## Identify missing fields

# %%
df.isnull().sum()
# Out:
# appid                0
# name                 0
# release_year         0
# release_date         0
# genres              66
# categories           7
# price                0
# recommendations      0
# developer           53
# publisher          183
# dtype: int64

# %% [markdown]
# ## Fill "genres" and "categories" missing values with "Other"

# %%
df[["genres", "categories"]] = df[["genres", "categories"]].fillna("Other")

df.isnull().sum()
# Out:
# appid                0
# name                 0
# release_year         0
# release_date         0
# genres               0
# categories           0
# price                0
# recommendations      0
# developer           53
# publisher          183
# dtype: int64

# %% [markdown]
# ## Fill "developer" and "publisher" missing values with "Unknown"

# %%
df[["developer", "publisher"]] = df[["developer", "publisher"]].fillna("Unknown")

df.isnull().sum()
# Out:
# appid              0
# name               0
# release_year       0
# release_date       0
# genres             0
# categories         0
# price              0
# recommendations    0
# developer          0
# publisher          0
# dtype: int64

# %% [markdown]
# ## Transform "release_date" to datetime

# %%
df["release_date"] = pd.to_datetime(df["release_date"], errors="coerce")

df["release_date"]
# Out:
# 0       2024-07-05
# 1       2025-07-25
# 2       2025-06-17
# 3       2023-11-10
# 4       2021-03-19
#            ...
# 65516   2024-07-31
# 65517   2025-03-03
# 65518   2021-02-04
# 65519   2024-04-13
# 65520   2021-06-28
# Name: release_date, Length: 65521, dtype: datetime64[ns]

# %% [markdown]
# ## Transform "price" to numeric values

# %%
df["price"]
# Out:
# 0         3.99
# 1         7.99
# 2        12.99
# 3        24.99
# 4         3.99
#          ...
# 65516    14.99
# 65517     4.99
# 65518    14.99
# 65519    15.99
# 65520     0.99
# Name: price, Length: 65521, dtype: float64

# %% [markdown]
# ## Drop duplicates "appid"

# %%
df = df.drop_duplicates(subset=["appid"])

df
# Out:
#          appid                        name  release_year release_date  \
# 0      3057270           Seafarer's Gambit          2024   2024-07-05
# 1      3822840    Capitalist Misadventures          2025   2025-07-25
# 2      3216640  The Beast and the Princess          2025   2025-06-17
# 3      2403620                 Air Twister          2023   2023-11-10
# 4      1538040                Horde Slayer          2021   2021-03-19
# ...        ...                         ...           ...          ...
# 65516  3097010           X Simulator Drone          2024   2024-07-31
# 65517  3304930        Retro Dungeon Slayer          2025   2025-03-03
# 65518  1461580            Molecule Builder          2021   2021-02-04
# 65519  1379120                    MechNest          2024   2024-04-13
# 65520  1580420     Ambidextrous Psychopath          2021   2021-06-28
#
#                                                genres  \
# 0                 Action;Adventure;Indie;RPG;Strategy
# 1                    Casual;Indie;Simulation;Strategy
# 2                            Adventure;Indie;Strategy
# 3                              Action;Adventure;Indie
# 4      Action;Adventure;Casual;Indie;RPG;Early Access
# ...                                               ...
# 65516                         Casual;Indie;Simulation
# 65517                       Action;Indie;Early Access
# 65518                            Simulation;Education
# 65519                                    Action;Indie
# 65520                                    Casual;Indie
#
#                                               categories  price  \
# 0                           Single-player;Family Sharing   3.99
# 1              Single-player;Save Anytime;Family Sharing   7.99
# 2      Single-player;Steam Achievements;Full controll...  12.99
# 3      Single-player;Steam Achievements;Full controll...  24.99
# 4      Single-player;Steam Achievements;Full controll...   3.99
# ...                                                  ...    ...
# 65516                       Single-player;Family Sharing  14.99
# 65517                       Single-player;Family Sharing   4.99
# 65518  Single-player;Tracked Controller Support;VR On...  14.99
# 65519  Single-player;Partial Controller Support;Famil...  15.99
# 65520                       Single-player;Family Sharing   0.99
#
#        recommendations              developer              publisher
# 0                    0  Bouncy Rocket Studios  Bouncy Rocket Studios
# 1                    0       Caramelo Studios       Caramelo Studios
# 2                    0             Libragames             Libragames
# 3                    0                 YS Net                   ININ
# 4                    0       Wagner Rodrigues       Wagner Rodrigues
# ...                ...                    ...                    ...
# 65516                0           Inonia Games           Inonia Games
# 65517                0       Hard Shark Games       Hard Shark Games
# 65518                0        Xennial Digital        Xennial Digital
# 65519                0            PoisonGames            PoisonGames
# 65520                0           Rylan Yancey           Rylan Yancey
#
# [65521 rows x 10 columns]

# %% [markdown]
# ## Normalize Genres (Explode pattern)

# %%
df['genres_list'] = df['genres'].str.split(';')

df_genres = df[['appid', 'name', 'genres_list']].explode('genres_list')
df_genres.rename(columns={'genres_list': 'genre'}, inplace=True)

df_genres.head()
# Out:
#      appid               name      genre
# 0  3057270  Seafarer's Gambit     Action
# 0  3057270  Seafarer's Gambit  Adventure
# 0  3057270  Seafarer's Gambit      Indie
# 0  3057270  Seafarer's Gambit        RPG
# 0  3057270  Seafarer's Gambit   Strategy
